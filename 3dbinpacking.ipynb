# %%
from py3dbp import Packer, Bin, Item

packer = Packer()

packer.add_bin(Bin("20' container", 235,239,590,25000))
packer.add_bin(Bin("40' container", 235,239,1203,27600))

packer.add_item(Item('Pallet 1', 85,200,125, 1500))#European Pallet with buffers
packer.add_item(Item('Pallet 1', 85,200,125, 1500))#European Pallet with buffers
packer.add_item(Item('Pallet 1', 85,200,125, 1500))#European Pallet with buffers
packer.add_item(Item('Pallet 1', 85,200,125, 1500))#European Pallet with buffers
packer.add_item(Item('Pallet 1', 85,200,125, 1500))#European Pallet with buffers
packer.add_item(Item('Pallet 1', 85,200,125, 1500))#European Pallet with buffers
packer.add_item(Item('Pallet 1', 85,200,125, 1500))#European Pallet with buffers
packer.add_item(Item('Pallet 1', 85,200,125, 1500))#European Pallet with buffers
packer.add_item(Item('Pallet 1', 85,200,125, 1500))#European Pallet with buffers
packer.add_item(Item('Pallet 1', 85,200,125, 1500))#European Pallet with buffers
packer.add_item(Item('Pallet 1', 85,200,125, 1500))#European Pallet with buffers
packer.add_item(Item('Pallet 1', 85,200,125, 1500))#European Pallet with buffers
packer.add_item(Item('Pallet 2', 105,125,200, 2080))#American Pallet with buffers
packer.add_item(Item('Pallet 2', 105,125,200, 2080))#American Pallet with buffers
packer.add_item(Item('Pallet 2', 105,125,200, 2080))#American Pallet with buffers
packer.add_item(Item('Pallet 2', 105,125,200, 2080))#American Pallet with buffers
packer.add_item(Item('Pallet 2', 105,125,200, 2080))#American Pallet with buffers
packer.add_item(Item('Pallet 2', 105,125,200, 2080))#American Pallet with buffers
packer.add_item(Item('Pallet 2', 105,125,200, 2080))#American Pallet with buffers
packer.add_item(Item('Pallet 2', 105,125,200, 2080))#American Pallet with buffers
packer.add_item(Item('Pallet 2', 105,125,200, 2080))#American Pallet with buffers
packer.add_item(Item('Pallet 2', 105,125,200, 2080))#American Pallet with buffers
packer.add_item(Item('Pallet 2', 105,125,200, 2080))#American Pallet with buffers
packer.add_item(Item('Pallet 2', 105,125,200, 2080))#American Pallet with buffers
packer.add_item(Item('Pallet 2', 105,125,200, 2080))#American Pallet with buffers

packer.pack(bigger_first=False, distribute_items=True, number_of_decimals=0)

for b in packer.bins:
    print(":::::::::::", b.string())

    print("FITTED ITEMS:")
    for item in b.items:
        print("====> ", item.string())

    print("UNFITTED ITEMS:")
    for item in b.unfitted_items:
        print("====> ", item.string())

    print("***************************************************")
    print("***************************************************")
# Out:
# ::::::::::: 20' container(235x239x590, max_weight:25000) vol(33137350)
# FITTED ITEMS:
# ====>  Pallet 1(85x200x125, weight: 1500) pos([0, 0, 0]) rt(0) vol(2125000)
# ====>  Pallet 1(85x200x125, weight: 1500) pos([Decimal('85'), 0, 0]) rt(0) vol(2125000)
# ====>  Pallet 1(85x200x125, weight: 1500) pos([0, 0, Decimal('125')]) rt(0) vol(2125000)
# ====>  Pallet 1(85x200x125, weight: 1500) pos([Decimal('85'), 0, Decimal('125')]) rt(0) vol(2125000)
# ====>  Pallet 1(85x200x125, weight: 1500) pos([0, 0, Decimal('250')]) rt(0) vol(2125000)
# ====>  Pallet 1(85x200x125, weight: 1500) pos([Decimal('85'), 0, Decimal('250')]) rt(0) vol(2125000)
# ====>  Pallet 1(85x200x125, weight: 1500) pos([0, 0, Decimal('375')]) rt(0) vol(2125000)
# ====>  Pallet 1(85x200x125, weight: 1500) pos([Decimal('85'), 0, Decimal('375')]) rt(0) vol(2125000)
# ====>  Pallet 1(85x200x125, weight: 1500) pos([0, 0, Decimal('500')]) rt(2) vol(2125000)
# UNFITTED ITEMS:
# ...
